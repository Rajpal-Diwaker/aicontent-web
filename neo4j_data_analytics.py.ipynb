# %%
from py2neo import Graph, Node, Relationship
graph = Graph(password="Techugo@1234")
nicole = Node("Person", name="Nicole")
graph.create(nicole)

# %%
import os
import sys
import time
import requests
from py2neo import Graph, Node, Relationship

def find_tweets(keyword, since_id=1):
    TWITTER_BEARER = os.environ["TWITTER_BEARER"]
    
    headers = dict(
        accept="application/json",
        Authorization='Bearer' + TWITTER_BEARER
    )
    
    payload = dict(
        q = keyword,
        count = 100,
        result_type = "recent",
        lang = "en",
        since_id = since_id
    )
    
    base_url = "https://api.twitter.com/1.1/search/tweets.json?"
    url = base_url + "q={q}&count={count}&result_type={result_type}&lang={lang}&since_id={since_id}".format(**payload)
    
    r = requests.get(url, headers=headers)
    tweets = r.json()["statuses"]
    
    return tweets

def upload_tweets(tweets):
    graph = Graph()
    
    for t in tweets:
        u = t['user']
        e = t['entities']
        
        tweet = graph.merge_one("Tweet", "id", t['id'])
        tweet.properties['text'] = t['text']
        tweet.push()
        
        user = graph.merge_one("User", "username", u['screen_name'])
        graph.create(Relationship(user, "POSTS", tweet))
        
        for h in e.get('hashtags', []):
            hashtag = graph.merge_one("Hashtag", "name", h['text'].lower())
            graph.create(Relationship(hashtag, "TAGS", tweet))
            
        for m in e.get('user_mentions', []):
            mension = graph.merge_one("User", "username", m['screen_name'])
            graph.create(Relationship(tweet, "MENTIONS", mension)) 
            
        reply = t.get('in_reply_to_status_id')  
        if reply:
            reply_tweet = graph.merge_one("Tweet", "id", reply)
            graph.create(Relationship(tweet, "REPLY_TO", reply_tweet))
            
            
        r = t.get('retweeted_status', {})
        r = r.get('id')
        
        if r:
            retweet = graph.merge_one("Tweet", "id", r)
            graph.create(Relationship(tweet, "RETWEETS", retweet))
            
def constraint(label, property):
    graph = Graph()
    schema = graph.schema
    if property not in schema.get_uniqueness_constraints(label):
        schema.create_uniqueness_constraint(label, property)
        
constraint("Tweet", "id") 
constraint("User", "username")
constraint("Hashtag", "name")

since_id = -1

while True:
    try:
        tweets = find_tweets(sys.argv[1], since_id=since_id)
        since_id = tweets[0].get('id')
        upload_tweets(tweets)
        time.sleep(60)
        
    except Exception as e:
        print(e)
        time.sleep(60)
        continue
# Out:
# ---------------------------------------------------------------------------
# AuthError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/py2neo/database.py in run(self, cypher, parameters, **kwparameters)
#     804                                              keys=[],
# --> 805                                              entities=entities))
#     806         except CypherError as error:
#
# ~/anaconda3/lib/python3.7/site-packages/py2neo/internal/connectors.py in run(self, statement, parameters, tx, graph, keys, entities)
#     284         if tx is None:
# --> 285             return self._run_1(statement, parameters, graph, keys, entities)
#     286         else:
#
# ~/anaconda3/lib/python3.7/site-packages/py2neo/internal/connectors.py in _run_1(self, statement, parameters, graph, keys, entities)
#     233     def _run_1(self, statement, parameters, graph, keys, entities):
# --> 234         cx = self.pool.acquire()
#     235         hydrator = PackStreamHydrator(version=cx.protocol_version, graph=graph, keys=keys, entities=entities)
#
# ~/anaconda3/lib/python3.7/site-packages/neobolt/direct.py in acquire(self, access_mode)
#     718     def acquire(self, access_mode=None):
# --> 719         return self.acquire_direct(self.address)
#     720
#
# ~/anaconda3/lib/python3.7/site-packages/neobolt/direct.py in acquire_direct(self, address)
#     611                     try:
# --> 612                         connection = self.connector(address, error_handler=self.connection_error_handler)
#     613                     except ServiceUnavailable:
#
# ~/anaconda3/lib/python3.7/site-packages/py2neo/internal/connectors.py in connector(address_, **kwargs)
#     224         def connector(address_, **kwargs):
# --> 225             return connect(address_, auth=cx_data["auth"], **kwargs)
#     226
#
# ~/anaconda3/lib/python3.7/site-packages/neobolt/direct.py in connect(address, **config)
#     975     else:
# --> 976         raise last_error
#
# ~/anaconda3/lib/python3.7/site-packages/neobolt/direct.py in connect(address, **config)
#     967             s, der_encoded_server_certificate = _secure(s, host, security_plan.ssl_context, **config)
# --> 968             connection = _handshake(s, address, der_encoded_server_certificate, **config)
#     969         except Exception as error:
#
# ~/anaconda3/lib/python3.7/site-packages/neobolt/direct.py in _handshake(s, resolved_address, der_encoded_server_certificate, **config)
#     935                                 **config)
# --> 936         connection.hello()
#     937         return connection
#
# ~/anaconda3/lib/python3.7/site-packages/neobolt/direct.py in hello(self)
#     248                      response=InitResponse(self, on_success=self.server.metadata.update))
# --> 249         self.sync()
#     250         self.packer.supports_bytes = self.server.supports("bytes")
#
# ~/anaconda3/lib/python3.7/site-packages/neobolt/direct.py in sync(self)
#     530             while not response.complete:
# --> 531                 detail_delta, summary_delta = self.fetch()
#     532                 detail_count += detail_delta
#
# ~/anaconda3/lib/python3.7/site-packages/neobolt/direct.py in fetch(self)
#     421         try:
# --> 422             return self._fetch()
#     423         except self.error_handler.known_errors as error:
#
# ~/anaconda3/lib/python3.7/site-packages/neobolt/direct.py in _fetch(self)
#     463             log_debug("[#%04X]  S: FAILURE %r", self.local_port, summary_metadata)
# --> 464             response.on_failure(summary_metadata or {})
#     465         else:
#
# ~/anaconda3/lib/python3.7/site-packages/neobolt/direct.py in on_failure(self, metadata)
#     777         if code == "Neo.ClientError.Security.Unauthorized":
# --> 778             raise AuthError(message)
#     779         else:
#
# AuthError: The client is unauthorized due to authentication failure.
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-4bcc28c7757b> in <module>
#      70         schema.create_uniqueness_constraint(label, property)
#      71
# ---> 72 constraint("Tweet", "id")
#      73 constraint("User", "username")
#      74 constraint("Hashtag", "name")
#
# <ipython-input-3-4bcc28c7757b> in constraint(label, property)
#      67     graph = Graph()
#      68     schema = graph.schema
# ---> 69     if property not in schema.get_uniqueness_constraints(label):
#      70         schema.create_uniqueness_constraint(label, property)
#      71
#
# ~/anaconda3/lib/python3.7/site-packages/py2neo/database.py in get_uniqueness_constraints(self, label)
#     634         """ Fetch a list of unique constraints for a label.
#     635         """
# --> 636         return self._get_indexes(label, "node_unique_property")
#     637
#     638
#
# ~/anaconda3/lib/python3.7/site-packages/py2neo/database.py in _get_indexes(self, label, t)
#     588     def _get_indexes(self, label, t=None):
#     589         indexes = []
# --> 590         for record in self.graph.run("CALL db.indexes"):
#     591             properties = []
#     592             if len(record) == 10:
#
# ~/anaconda3/lib/python3.7/site-packages/py2neo/database.py in run(self, cypher, parameters, **kwparameters)
#     524         :return:
#     525         """
# --> 526         return self.begin(autocommit=True).run(cypher, parameters, **kwparameters)
#     527
#     528     def separate(self, subgraph):
#
# ~/anaconda3/lib/python3.7/site-packages/py2neo/database.py in run(self, cypher, parameters, **kwparameters)
#     805                                              entities=entities))
#     806         except CypherError as error:
# --> 807             raise GraphError.hydrate({"code": error.code, "message": error.message})
#     808         finally:
#     809             if not self.transaction:
#
# ~/anaconda3/lib/python3.7/site-packages/py2neo/database.py in hydrate(cls, data)
#     651         code = data["code"]
#     652         message = data["message"]
# --> 653         _, classification, category, title = code.split(".")
#     654         if classification == "ClientError":
#     655             try:
#
# AttributeError: 'NoneType' object has no attribute 'split'
