# %%
import pandas as pd
pd.options.display.max_columns = 200
pd.options.mode.chained_assignment = None

from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
stop = set(stopwords.words('english'))
from string import punctuation

from collections import Counter
import re
import numpy as np

from tqdm import tqdm_notebook
tqdm_notebook().pandas()

import matplotlib.pyplot as plt

data = pd.read_csv('./data-model/news.csv')
data = data.drop_duplicates('description')
data = data[~data['description'].isnull()]
data = data[(data.description.map(len) > 140) & (data.description.map(len) <= 300)]
data = data.sample(100, random_state=42)
data.reset_index(inplace=True, drop=True)

stop_words = []

f = open('./data-model/stopwords.txt', 'r')
for l in f.readlines():
    stop_words.append(l.replace('\n', ''))
    
additional_stop_words = ['t', 'will']
stop_words += additional_stop_words

def _removeNonAscii(s): 
    return "".join(i for i in s if ord(i)<128)

def clean_text(text):
    text = text.lower()
    text = re.sub(r"what's", "what is ", text)
    text = text.replace('(ap)', '')
    text = re.sub(r"\'s", " is ", text)
    text = re.sub(r"\'ve", " have ", text)
    text = re.sub(r"can't", "cannot ", text)
    text = re.sub(r"n't", " not ", text)
    text = re.sub(r"i'm", "i am ", text)
    text = re.sub(r"\'re", " are ", text)
    text = re.sub(r"\'d", " would ", text)
    text = re.sub(r"\'ll", " will ", text)
    text = re.sub(r'\W+', ' ', text)
    text = re.sub(r'\s+', ' ', text)
    text = re.sub(r"\\", "", text)
    text = re.sub(r"\'", "", text)    
    text = re.sub(r"\"", "", text)
    text = re.sub('[^a-zA-Z ?!]+', '', text)
    text = _removeNonAscii(text)
    text = text.strip()
    return text

def tokenizer(text):
    text = clean_text(text)    
    tokens = [word_tokenize(sent) for sent in sent_tokenize(text)]
    tokens = list(reduce(lambda x,y: x+y, tokens))
    tokens = list(filter(lambda token: token not in (stop_words + list(punctuation)) , tokens))
    return tokens

def reduce(function, iterable, initializer=None):
    it = iter(iterable)
    if initializer is None:
        value = next(it)
    else:
        value = initializer
    for element in it:
        value = function(value, element)
    return value

data['description'] = data['description'].map(lambda d: str(d))
data['tokens'] = data['description'].progress_map(lambda d: tokenizer(d))

def keywords(category):
    tokens = data[data['category'] == category]['tokens']
    alltokens = []
    for token_list in tokens:
        alltokens += token_list
    counter = Counter(alltokens)
    return counter.most_common(10)

# warnings.filterwarnings(action='ignore', category=UserWarning, module='gensim')

import gensim
import gensim.corpora as corpora
from gensim import matutils
from gensim.models import CoherenceModel

aux = data.copy()

bigram = gensim.models.Phrases(aux['tokens'], min_count=5, threshold=100)
bigram_mod = gensim.models.phrases.Phraser(bigram)
aux['tokens_bigram'] = aux['tokens'].progress_map(lambda tokens: bigram_mod[tokens])

id2word = corpora.Dictionary(aux['tokens_bigram'])
texts = aux['tokens_bigram'].values
corpus = [id2word.doc2bow(text) for text in texts]

def LDA_model(num_topics, passes=1):
    return gensim.models.ldamodel.LdaModel(corpus=tqdm_notebook(corpus, leave=False),
                                               id2word=id2word,
                                               num_topics=num_topics, 
                                               random_state=100,
                                               eval_every=10,
                                               chunksize=2000,
                                               passes=passes,
                                               per_word_topics=True
                                            )

def compute_coherence(model):
    coherence = CoherenceModel(model=model, 
                           texts=aux['tokens_bigram'].values,
                           dictionary=id2word, coherence='c_v')
    return coherence.get_coherence()

def display_topics(model):
    topics = model.show_topics(num_topics=model.num_topics, formatted=False, num_words=10)
    topics = map(lambda c: map(lambda cc: cc[0], c[1]), topics)
    df = pd.DataFrame(topics)
    df.index = ['topic_{0}'.format(i) for i in range(model.num_topics)]
    df.columns = ['keyword_{0}'.format(i) for i in range(1, 10+1)]
    return df

def explore_models(df, rg=range(5, 25)):
    id2word = corpora.Dictionary(df['tokens_bigram'])
    texts = df['tokens_bigram'].values
    corpus = [id2word.doc2bow(text) for text in texts]

    models = []
    coherences = []
    
    for num_topics in tqdm_notebook(rg, leave=False):
        lda_model = LDA_model(num_topics, passes=5)
        models.append(lda_model)
        coherence = compute_coherence(lda_model)
        coherences.append(coherence)
      

    fig = plt.figure(figsize=(15, 5))
    plt.title('Choosing the optimal number of topics')
    plt.xlabel('Number of topics')
    plt.ylabel('Coherence')
    plt.grid(True)
    plt.plot(rg, coherences)
    
    return coherences, models

best_model = LDA_model(num_topics=50, passes=5)

dff = display_topics(model=best_model)
from IPython.display import display, HTML

display(dff)

display(aux)
# Out:
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
#               keyword_1    keyword_2    keyword_3      keyword_4  \
# topic_0          carbon       friday       states         change
# topic_1       president  impeachment       senate          trial
# topic_2      australian        jones         hope       wildlife
# topic_3         economy        boost      tariffs          china
# topic_4           india     thursday     national         friday
# topic_5          donald          job    illegally          state
# topic_6            uber       gaming      elevate            air
# topic_7          points      pearson      actions           zone
# topic_8           china      windows    microsoft       chromium
# topic_9       satellite        quiet      polemic          india
# topic_10       european         work       united       training
# topic_11      overwatch         year       effort         arcade
# topic_12         donald      cerrone     prepares          conor
# topic_13      president         lakh        trial         senate
# topic_14       swapping       switch      mission          style
# topic_15         police       monday      orleans           game
# topic_16         points      pearson      actions           zone
# topic_17          brand         poco       xiaomi        created
# topic_18       thursday       opened      leading       senators
# topic_19        remnant       martin       luther          court
# topic_20        service    announced        enter        comcast
# topic_21         weekly        tyler   newsletter             bi
# topic_22         police       locker     stemming         issued
# topic_23          apple       inside       person      structure
# topic_24        company        minaj       amazon       trillion
# topic_25          sworn         week     oklahoma        justice
# topic_26        weekend     juventus        tight          marco
# topic_27       trillion       dollar        apple          judge
# topic_28         friday      supreme      seafood       khamenei
# topic_29       coaching         dawn      bengals     randomness
# topic_30            cnn         iran         york         donald
# topic_31       thursday       season      devices  multinational
# topic_32      pneumonia     thailand       second       delaware
# topic_33    upernatural         star  inspiration      character
# topic_34         cooled        trade     bruising     investment
# topic_35         points      pearson      actions           zone
# topic_36        missile       attack      airbase          place
# topic_37         friday         game    developer          train
# topic_38           card       credit    sampdoria           quiz
# topic_39        updated        today         game         window
# topic_40         points      pearson      actions           zone
# topic_41         vrabel           bt           uk         launch
# topic_42           test         july         club            day
# topic_43     australian      country        trump         reborn
# topic_44         parnas    president    described            lev
# topic_45  investigating     advanced   efficiency       recreate
# topic_46            top      company        green          stock
# topic_47         coming     nintendo         mint          based
# topic_48         points      pearson      actions           zone
# topic_49         police    cleveland   scientists   cosmological
#
#               keyword_5      keyword_6   keyword_7       keyword_8  \
# topic_0         efforts        climate     dioxide         achieve
# topic_1              op          stand    articles           trump
# topic_2         charity          weeks   defensive         studios
# topic_3         beijing         olcott     analyst       stabilize
# topic_4            term          south    monarchy          enters
# topic_5      ambassador        ukraine     emerged      maintained
# topic_6        vertical       complete      picked         landing
# topic_7         watford           side  relegation          reborn
# topic_8            edge         reilly    industry        investor
# topic_9      unrivalled       champion      shared            gsat
# topic_10  investigators          delta        crew        expected
# topic_11          event         annual     ukraine  investigations
# topic_12         better          place       years             ago
# topic_13    impeachment       released    justices        sangeeta
# topic_14  whistleblower       mulvaney      system        security
# topic_15      cleveland    interaction        room        thursday
# topic_16        watford           side  relegation          reborn
# topic_17           jain             vp        span         chinese
# topic_18      president           oath     intense       bushfires
# topic_19         german       semitism        high        preached
# topic_20       unveiled   nbcuniversal        july          bundle
# topic_21           time         xiaomi        poco           brand
# topic_22         arrest        officer     beckham           title
# topic_23            job      labyrinth      single    bureaucratic
# topic_24         fourth         branch    unveiled           apple
# topic_25       thursday          james    senators           trial
# topic_26     fiorentina          lecce      napoli       francisco
# topic_27         passed         highly        club             nfl
# topic_28           slap           iran     strikes         missile
# topic_29        horizon       released         nfl           staff
# topic_30             az  congressional   poisonous         service
# topic_31           iran    destruction   including            best
# topic_32           sars          virus     semitic          spread
# topic_33           best            tar        eric           actor
# topic_34          years          boost    stimulus             war
# topic_35        watford           side  relegation          reborn
# topic_36        service     casualties        week            asad
# topic_37          round          april   september             nfl
# topic_38           best         zapata      habits           quick
# topic_39      september            won        call     multiplayer
# topic_40        watford           side  relegation          reborn
# topic_41           year         system      ravens          titans
# topic_42           root          worth        amir             joe
# topic_43      residents        animals     destiny           nigel
# topic_44      drawbacks          cohen     michael          donald
# topic_45          birds        process        step          unique
# topic_46       investor          rated       gains           funds
# topic_47       revealed        finance      mobile        pinnacle
# topic_48        watford           side  relegation          reborn
# topic_49       galaxies        warrant     subject          reason
#
#                keyword_9  keyword_10
# topic_0          address   microsoft
# topic_1             wall        vice
# topic_2            field   charities
# topic_3          reduced  confidence
# topic_4            woman   delivered
# topic_5            trump      pompeo
# topic_6              ces        best
# topic_7        ayatollah       point
# topic_8   transportation   introduce
# topic_9         reaction      public
# topic_10      technology       milan
# topic_11           lunar        call
# topic_12        mcgregor         ufc
# topic_13         dhingra      sengar
# topic_14         weapons    national
# topic_15           odell    national
# topic_16       ayatollah       point
# topic_17           kumar       giant
# topic_18         farmers       quiet
# topic_19            ugly   centuries
# topic_20         xfinity        flex
# topic_21           tough     costars
# topic_22        receiver     warrant
# topic_23            year    greatest
# topic_24           nicki      attain
# topic_25       impartial     dealing
# topic_26         packers        hold
# topic_27        alphabet      member
# topic_28        products   ayatollah
# topic_29         coaches        head
# topic_30       investors      leader
# topic_31       passenger    notified
# topic_32           japan      family
# topic_33          kripke     creator
# topic_34         weakest      united
# topic_35       ayatollah       point
# topic_36              al     injured
# topic_37         playing     projekt
# topic_38            euro       basis
# topic_39         release       delay
# topic_40       ayatollah       point
# topic_41          europe        aims
# topic_42          series       final
# topic_43           going   developer
# topic_44        devotion   fanatical
# topic_45             air       areas
# topic_46         shaping      google
# topic_47             app    masahiro
# topic_48       ayatollah       point
# topic_49        receiver        move
#                                         author  \
# 0                                 Manish Singh
# 1                                  JILL COLVIN
# 2                        Football Italia Staff
# 3                            Michael McWhertor
# 4                                    BBC Sport
# ..                                         ...
# 95  KATE BRUMBACK, DEEPTI HAJELA and AMY TAXIN
# 96                               David Brennan
# 97                             Hayley Peterson
# 98                                LISA MASCARO
# 99                            John Haltiwanger
#
#                                                 title  \
# 0       Xiaomi spins off POCO as an independent brand
# 1   Trump campaign tries robust outreach to expand...
# 2                Bonucci discussed return with ultras
# 3   Overwatch Lunar New Year 2020 skins, dates, an...
# 4   Australian Open 2020: Margaret Court to be 're...
# ..                                                ...
# 95  AP visits immigration courts across US, finds ...
# 96  Iran Plane Investigation Will Draw on Lessons ...
# 97  Amazon contractor Pinnacle Logistics to lay of...
# 98  Trump's trial begins at the start of an electi...
# 99  Trump tweets in all-caps that he 'JUST GOT IMP...
#
#                                           description  \
# 0   Xiaomi said today it is spinning off POCO, a s...
# 1   WASHINGTON (AP) — Selfies on a “Women for Trum...
# 2   Messages between Leonardo Bonucci and a leadin...
# 3   The Year of the Rat begins in Overwatch with L...
# 4   Margaret Court was a quiet champion, unrivalle...
# ..                                                ...
# 95  LUMPKIN, Ga. (AP) — In a locked, guarded court...
# 96  Representatives for the multinational Internat...
# 97  Texas-based Pinnacle Logistics plans to lay of...
